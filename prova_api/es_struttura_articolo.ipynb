# %% [markdown]
# Esempio di articolo generico (tipo un nostro articolo reviewed)

# %%
from crossref_commons.sampling import get_sample
import pprint

# Definisci il filtro per gli articoli accademici
filter = {'type': 'journal-article'}

# Ottieni un campione di articoli accademici
sample = get_sample(size=3, filter=filter)

# Fai qualcosa con i dati ottenuti, ad esempio stampali
for item in sample:
    pprint.pprint(item)
# Out:
# {'DOI': '10.1080/14664658.2015.1052252',
#  'ISSN': ['1466-4658', '1743-7903'],
#  'URL': 'http://dx.doi.org/10.1080/14664658.2015.1052252',
#  'alternative-id': ['10.1080/14664658.2015.1052252'],
#  'assertion': [{'label': 'Peer Review Statement',
#                 'name': 'peerreview_statement',
#                 'order': 1,
#                 'value': 'The publishing and review policy for this title is '
#                          'described in its Aims & Scope.'},
#                {'URL': 'http://www.tandfonline.com/action/journalInformation?show=aimsScope&journalCode=fanc20',
#                 'label': 'Aim & Scope',
#                 'name': 'aims_and_scope_url',
#                 'order': 2,
#                 'value': 'http://www.tandfonline.com/action/journalInformation?show=aimsScope&journalCode=fanc20'}],
#  'author': [{'affiliation': [],
#              'family': 'Strange',
#              'given': 'Thomas',
#              'sequence': 'first'}],
# ...

# %% [markdown]
# Esempio di review

# %%
    {
        "URL": "http://dx.doi.org/10.7554/elife.18481.032",
        "resource": {
            "primary": {
                "URL": "https://elifesciences.org/articles/18481#SA1"
            }
        },
        "member": "4374",
        "score": 0.0,
        "created": {
            "date-parts": [
                [
                    2017,
                    6,
                    22
                ]
            ],
            "date-time": "2017-06-22T13:00:17Z",
            "timestamp": 1498136417000
        },
        "license": [
            {
                "start": {
                    "date-parts": [
                        [
                            2016,
                            8,
                            8
                        ]
                    ],
                    "date-time": "2016-08-08T00:00:00Z",
                    "timestamp": 1470614400000
                },
                "content-version": "unspecified",
                "delay-in-days": 0,
                "URL": "http://creativecommons.org/licenses/by/4.0/"
            }
        ],
        "issued": {
            "date-parts": [
                [
                    2016,
                    8,
                    8
                ]
            ]
        },
        "review": {
            "type": "editor-report",
            "stage": "pre-publication"
        },
        "prefix": "10.7554",
        "reference-count": 0,
        "indexed": {
            "date-parts": [
                [
                    2022,
                    4,
                    5
                ]
            ],
            "date-time": "2022-04-05T09:37:55Z",
            "timestamp": 1649151475579
        },
        "DOI": "10.7554/elife.18481.032",
        "is-referenced-by-count": 0,
        "published": {
            "date-parts": [
                [
                    2016,
                    8,
                    8
                ]
            ]
        },
        "published-print": {
            "date-parts": [
                [
                    2016,
                    8,
                    8
                ]
            ]
        },
        "content-domain": {
            "domain": []
        },
        "title": [
            "Decision letter: Genetic specification of left\u2013right asymmetry in the diaphragm muscles and their motor innervation"
        ],
        "source": "Crossref",
        "type": "peer-review",
        "publisher": "eLife Sciences Publications, Ltd",
        "references-count": 0,
        "deposited": {
            "date-parts": [
                [
                    2019,
                    11,
                    13
                ]
            ],
            "date-time": "2019-11-13T05:08:44Z",
            "timestamp": 1573621724000
        },
        "relation": {
            "is-review-of": [
                {
                    "id-type": "doi",
                    "id": "10.7554/eLife.18481",
                    "asserted-by": "subject"
                }
            ]
        },
        "editor": [
            {
                "ORCID": "http://orcid.org/0000-0001-6253-505X",
                "authenticated-orcid": true,
                "given": "Carol A",
                "family": "Mason",
                "sequence": "first",
                "affiliation": [
                    {
                        "name": "Columbia University, United States"
                    }
                ]
            }
        ]
    },
